# %% [markdown]
# # Colab Bootstrap
#
# Mount Drive, clone the GitHub repo, install dependencies, and verify the runtime.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from pathlib import Path

DRIVE_PROJECT = Path('/content/drive/MyDrive/drug-repurpose')
for path in [
    DRIVE_PROJECT / 'data/raw/optimuskg',
    DRIVE_PROJECT / 'data/raw/hetionet',
    DRIVE_PROJECT / 'data/interim',
    DRIVE_PROJECT / 'data/processed',
    DRIVE_PROJECT / 'data/manifests',
    DRIVE_PROJECT / 'artifacts/embeddings',
    DRIVE_PROJECT / 'artifacts/models',
    DRIVE_PROJECT / 'artifacts/checkpoints',
    DRIVE_PROJECT / 'reports',
    DRIVE_PROJECT / 'runs',
]:
    path.mkdir(parents=True, exist_ok=True)

DRIVE_PROJECT

# %% [markdown]
# The GitHub repository URL is prefilled below.

# %%
GITHUB_REPO_URL = 'https://github.com/aryanrisi8/drug-repurpose.git'
REPO_DIR = Path('/content/drug-repurpose')

if GITHUB_REPO_URL:
    if REPO_DIR.exists():
        # %cd /content/drug-repurpose
        # !git pull
    else:
        # %cd /content
        # !git clone {GITHUB_REPO_URL}
        # %cd /content/drug-repurpose
else:
    print('Set GITHUB_REPO_URL before cloning.')

# %%
if REPO_DIR.exists():
    # %cd /content/drug-repurpose
    # !pip install -r requirements.txt

# %%
import os
import torch

print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
print('Drive project:', DRIVE_PROJECT)
print('Repo dir:', REPO_DIR)
